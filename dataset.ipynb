# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\jjate\Downloads\bestSelling_games.csv")

# %% [markdown]
# # Inspecao basica

# %%
df.head()
# Out:
#                 game_name  reviews_like_rate  all_reviews_number  \
# 0        Counter-Strike 2                 86             8803754
# 1     PUBG: BATTLEGROUNDS                 59             2554482
# 2   ELDEN RING NIGHTREIGN                 77               53426
# 3  The Last of Us™ Part I                 79               45424
# 4   Red Dead Redemption 2                 92              672140
#
#    release_date           developer  \
# 0  21 Aug, 2012               Valve
# 1  21 Dec, 2017    PUBG Corporation
# 2  30 May, 2025  FromSoftware, Inc.
# 3  28 Mar, 2023     Naughty Dog LLC
# 4   5 Dec, 2019      Rockstar Games
#
#                                    user_defined_tags supported_os  \
# 0                              FPS, Action, Tactical   win, linux
# 1                Survival, Shooter, Action, Tactical          win
# 2               Souls-like, Open World, Fantasy, RPG          win
# 3              Story Rich, Shooter, Survival, Horror          win
# 4  Open World, Story Rich, Adventure, Realistic, ...          win
#
#                                  supported_languages  price  \
# 0  English, Czech, Danish, Dutch, Finnish, French...   0.00
# 1  English, Korean, Simplified Chinese, French, G...   0.00
# 2  English, Japanese, French, Italian, German, Sp...  25.99
# 3  English, Italian, Spanish - Spain, Czech, Dutc...  59.99
# 4  English, French, Italian, German, Spanish - Sp...  59.99
#
#                                       other_features  age_restriction  rating  \
# 0  Cross-Platform Multiplayer, Steam Trading Card...               17    3.20
# 1  Online PvP, Stats, Remote Play on Phone, Remot...               13    3.10
# 2  Single-player, Online Co-op, Steam Achievement...               17    3.96
# 3  Single-player, Steam Achievements, Steam Tradi...               17    4.10
# 4  Single-player, Online PvP, Online Co-op, Steam...               17    4.32
#
#    difficulty  length  estimated_downloads
# 0           4      80            306170000
# 1           4      73            162350000
# 2           4      50               840000
# 3           3      24              2000000
# 4           3      80             21610000

# %%
df.tail()
# Out:
#                  game_name  reviews_like_rate  all_reviews_number  \
# 2375          Wooden House                 38                 147
# 2376  Shoot. Push. Repeat.                 84                  65
# 2377        X2: The Threat                 83                 416
# 2378              !AnyWay!                 71                 498
# 2379        UBERMOSH:OMEGA                 93                 314
#
#      release_date       developer       user_defined_tags supported_os  \
# 2375  5 Sep, 2016         GDNomaD              Simulation          win
# 2376  8 Jun, 2020         CrewLab              Puzzle, 2D          win
# 2377  3 Dec, 2003         Egosoft    Strategy, Simulation          win
# 2378  6 Jun, 2018        EYEFRONT          Platformer, 2D          win
# 2379  8 Nov, 2019  Walter Machado  Action, Pixel Graphics          win
#
#                                     supported_languages  price  \
# 2375                                            English   0.89
# 2376  English, French, Italian, German, Spanish - Sp...   0.89
# 2377  English, French, German, Italian, Spanish - Sp...   2.99
# 2378  English, Russian, French, Italian, German, Pol...   1.35
# 2379  English, French, Italian, German, Spanish - Sp...   0.89
#
#                                          other_features  age_restriction  \
# 2375  Single-player, Steam Trading Cards, Family Sha...               17
# 2376  Single-player, Steam Achievements, Steam Cloud...                0
# 2377  Single-player, Captions available, Steam Cloud...               13
# 2378  Single-player, Steam Achievements, Steam Tradi...                0
# 2379  Single-player, Steam Achievements, Family Sharing               13
#
#       rating  difficulty  length  estimated_downloads
# 2375    1.24           3       1               221000
# 2376    3.64           1       3                 2700
# 2377    3.61           4      60                47500
# 2378    3.00           3       2                79000
# 2379    4.17           5      12                14000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   game_name            2380 non-null   str
#  1   reviews_like_rate    2380 non-null   int64
#  2   all_reviews_number   2380 non-null   int64
#  3   release_date         2380 non-null   str
#  4   developer            2380 non-null   str
#  5   user_defined_tags    2380 non-null   str
#  6   supported_os         2380 non-null   str
#  7   supported_languages  2380 non-null   str
#  8   price                2380 non-null   float64
#  9   other_features       2380 non-null   str
#  10  age_restriction      2380 non-null   int64
#  11  rating               2380 non-null   float64
#  12  difficulty           2380 non-null   int64
#  13  length               2380 non-null   int64
#  14  estimated_downloads  2380 non-null   int64
# dtypes: float64(2), int64(6), str(7)
# memory usage: 942.5 KB

# %%
df.describe()
# Out:
#        reviews_like_rate  all_reviews_number        price  age_restriction  \
# count        2380.000000        2.380000e+03  2380.000000      2380.000000
# mean           82.413445        3.161508e+04    10.509130        10.605462
# std            12.643745        2.137197e+05    11.344576         6.395752
# min            20.000000        1.000000e+01     0.000000         0.000000
# 25%            76.000000        3.420000e+02     2.990000        10.000000
# 50%            85.000000        2.106500e+03     7.990000        13.000000
# 75%            92.000000        1.303000e+04    12.490000        17.000000
# max           100.000000        8.803754e+06    79.990000        17.000000
#
#             rating   difficulty       length  estimated_downloads
# count  2380.000000  2380.000000  2380.000000         2.380000e+03
# mean      3.228017     2.864706    22.965126         2.523007e+06
# std       0.771203     0.975194    21.247556         1.118283e+07
# min       0.390000     1.000000     1.000000         9.000000e+01
# 25%       2.750000     2.000000     6.000000         3.500000e+04
# 50%       3.380000     3.000000    16.000000         2.171500e+05
# 75%       3.810000     3.000000    34.000000         1.380000e+06
# max       4.830000     5.000000    80.000000         3.061700e+08

# %%
df.shape
# Out:
# (2380, 15)

# %% [markdown]
# ### Frequencia dos itens das colunas

# %%
print(df['developer'].value_counts())
print("--------------")
print(df['user_defined_tags'].value_counts())
print("--------------")
print(df['supported_os'].value_counts())
# Out:
# developer
# Valve                17
# Arc System Works     16
# CAPCOM Co., Ltd.     12
# CREATIVE ASSEMBLY    11
# Ubisoft Montreal     10
#                      ..
# Snkl Studio           1
# postpunkpl            1
# Repa Games            1
# CrewLab               1
# EYEFRONT              1
# Name: count, Length: 1806, dtype: int64
# --------------
# user_defined_tags
# Simulation, Management              29
# FPS, Action                         27
# Action, FPS                         25
# Simulation                          23
# Cute, Puzzle                        22
#                                     ..
# Anime, Puzzle, Cute, 2D              1
# FPS, Pixel Graphics                  1
# Action, Strategy, Tactical, RPG      1
# Cute, Anime, Puzzle                  1
# Action, Simulation, RPG, Driving     1
# Name: count, Length: 1649, dtype: int64
# --------------
# supported_os
# win                  1724
# win, mac, linux       307
# win, mac              288
# win, linux             59
# win, linux, music       1
# win, mac, linux,        1
# Name: count, dtype: int64

# %%
print(df['age_restriction'].value_counts())
print("--------------")
print(df['price'].value_counts())
print("--------------")
print(df['supported_languages'].value_counts())
# Out:
# age_restriction
# 17    743
# 13    620
# 0     562
# 10    455
# Name: count, dtype: int64
# --------------
# price
# 7.99     177
# 0.00     169
# 10.49    163
# 14.99    133
# 2.99     128
#         ...
# 2.52       1
# 1.52       1
# 4.19       1
# 2.29       1
# 1.35       1
# Name: count, Length: 149, dtype: int64
# --------------
# supported_languages
# English                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               323
# English, Japanese, Simplified Chinese                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  52
# English, Russian                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       25
# English, Simplified Chinese                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            24
# English, Japanese                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      20
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# English, Russian, French, Italian, German, Spanish - Spain, Arabic, Bulgarian, Portuguese - Brazil, Hungarian, Vietnamese, Greek, Danish, Indonesian, Spanish - Latin America, Traditional Chinese, Simplified Chinese, Korean, Dutch, Norwegian, Polish, Portuguese - Portugal, Romanian, Thai, Turkish, Ukrainian, Finnish, Czech, Swedish, Japanese, Azerbaijani, Albanian, Amharic, Armenian, Assamese, Afrikaans, Basque, Belarusian, Bangla, Bosnian, Valencian, Welsh, Wolof, Galician, Georgian, Gujarati, Dari, Zulu, Hebrew, Igbo, Irish, Icelandic, Yoruba, Kazakh, Kannada, Catalan, Quechua, Kinyarwanda, K'iche', Konkani, Xhosa, Khmer, Kyrgyz, Latvian, Lithuanian, Luxembourgish, Macedonian, Malay, Malayalam, Maltese, Maori, Marathi, Mongolian, Nepali, Odia, Punjabi (Gurmukhi), Punjabi (Shahmukhi), Persian, Serbian, Sotho, Sinhala, Sindhi, Slovak, Slovenian, Sorani, Swahili, Tajik, Tamil, Tatar, Telugu, Tigrinya, Tswana, Turkmen, Uzbek, Uyghur, Urdu, Filipino, Hausa, Hindi, Croatian, Cherokee, Scots, Estonian      1
# English, Simplified Chinese, French, Italian, German, Spanish - Spain, Danish, Ukrainian, Russian, Bulgarian, Hungarian, Turkish, Greek, Norwegian, Czech, Japanese, Polish, Thai, Swedish, Traditional Chinese, Romanian, Finnish, Dutch, Portuguese - Portugal, Portuguese - Brazil, Spanish - Latin America, Vietnamese, Arabic, Korean                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# English, French, Italian, German, Spanish - Spain, Korean, Polish, Portuguese - Portugal, Portuguese - Brazil, Russian, Simplified Chinese, Spanish - Latin America, Traditional Chinese                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# English, Russian, French, Italian, German, Polish, Ukrainian, Swedish, Simplified Chinese, Bulgarian, Danish, Finnish, Czech                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# English, French, Italian, German, Spanish - Spain, Bulgarian, Simplified Chinese, Traditional Chinese, Korean, Danish, Spanish - Latin America, Finnish, Greek, Dutch, Hungarian, Japanese, Norwegian, Polish, Portuguese - Brazil, Portuguese - Portugal, Romanian, Russian, Swedish, Thai, Czech, Turkish, Ukrainian, Vietnamese, Arabic, Afrikaans, Albanian, Amharic, Armenian, Assamese, Azerbaijani, Basque, Bangla, Belarusian, Bosnian, Kannada, Catalan, Kazakh, Cherokee, Sinhala, Konkani, Croatian, Dari, Slovak, Slovenian, Estonian, Filipino, Galician, Welsh, Georgian, Gujarati, Hausa, Hebrew, Hindi, Igbo, Indonesian, Yoruba, Irish, Icelandic, Khmer, Latvian, Lithuanian, Luxembourgish, Macedonian, Malayalam, Malay, Maltese, Maori, Marathi, Mongolian, Nepali, Odia, Punjabi (Gurmukhi), Punjabi (Shahmukhi), Persian, K'iche', Kinyarwanda, Kyrgyz, Quechua, Sotho, Sindhi, Sorani, Swahili, Serbian, Tajik, Tigrinya, Tswana, Turkmen, Tatar, Tamil, Telugu, Uyghur, Wolof, Urdu, Uzbek, Valencian, Xhosa, Zulu, Scots      1
# Name: count, Length: 1606, dtype: int64

# %%
print(df['rating'].value_counts())
print("--------------")
print(df['difficulty'].value_counts())
print("--------------")
print(df['length'].value_counts())
# Out:
# rating
# 3.50    88
# 4.00    77
# 3.00    76
# 3.25    35
# 3.75    28
#         ..
# 1.57     1
# 0.39     1
# 1.37     1
# 1.35     1
# 1.24     1
# Name: count, Length: 351, dtype: int64
# --------------
# difficulty
# 3    1073
# 2     507
# 4     467
# 1     237
# 5      96
# Name: count, dtype: int64
# --------------
# length
# 4     130
# 1     105
# 2     102
# 3     100
# 8      98
#      ...
# 72      6
# 61      5
# 78      4
# 69      4
# 56      3
# Name: count, Length: 80, dtype: int64

# %% [markdown]
# ### Shapes

# %%
print('ratings:', (df.rating.value_counts()).shape)
print('developers:', (df.developer.value_counts()).shape)
print('difficulty:', (df.difficulty.value_counts()).shape)
print('age_restriction:', (df.age_restriction.value_counts()).shape)
# Out:
# ratings: (351,)
# developers: (1806,)
# difficulty: (5,)
# age_restriction: (4,)

# %% [markdown]
# ### Quantidade de valores unicos

# %%
print('ratings:', (df.rating.value_counts()).nunique())
print('difficulty:', (df.difficulty.value_counts()).nunique())
print('age_restriction:', (df.age_restriction.value_counts()).nunique())
print('developer:', (df.developer.value_counts()).nunique())
print('supported_os:', (df.supported_os.value_counts()).nunique())
print('supported_languages:', (df.supported_languages.value_counts()).nunique())
print('other_features:', (df.other_features.value_counts()).nunique())
# Out:
# ratings: 28
# difficulty: 5
# age_restriction: 4
# developer: 14
# supported_os: 5
# supported_languages: 19
# other_features: 25

# %% [markdown]
# ### Valores nulos

# %%
df.isna().sum()
# Out:
# game_name              0
# reviews_like_rate      0
# all_reviews_number     0
# release_date           0
# developer              0
# user_defined_tags      0
# supported_os           0
# supported_languages    0
# price                  0
# other_features         0
# age_restriction        0
# rating                 0
# difficulty             0
# length                 0
# estimated_downloads    0
# dtype: int64

# %% [markdown]
# ### Valores duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Converter string para datetime

# %%
df['release_date']=pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# game_name                         str
# reviews_like_rate               int64
# all_reviews_number              int64
# release_date           datetime64[us]
# developer                         str
# user_defined_tags                 str
# supported_os                      str
# supported_languages               str
# price                         float64
# other_features                    str
# age_restriction                 int64
# rating                        float64
# difficulty                      int64
# length                          int64
# estimated_downloads             int64
# dtype: object

# %% [markdown]
# ### Criar nova coluna ano de lancamento

# %%
df['release_year'] = df['release_date'].dt.year
df.info()
df.head()
df['release_year'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   game_name            2380 non-null   str
#  1   reviews_like_rate    2380 non-null   int64
#  2   all_reviews_number   2380 non-null   int64
#  3   release_date         2380 non-null   datetime64[us]
#  4   developer            2380 non-null   str
#  5   user_defined_tags    2380 non-null   str
#  6   supported_os         2380 non-null   str
#  7   supported_languages  2380 non-null   str
#  8   price                2380 non-null   float64
#  9   other_features       2380 non-null   str
#  10  age_restriction      2380 non-null   int64
#  11  rating               2380 non-null   float64
#  12  difficulty           2380 non-null   int64
#  13  length               2380 non-null   int64
#  14  estimated_downloads  2380 non-null   int64
#  15  release_year         2380 non-null   int32
# dtypes: datetime64[us](1), float64(2), int32(1), int64(6), str(6)
# memory usage: 924.5 KB
# release_year
# 2024    469
# 2025    323
# 2023    293
# 2022    186
# 2021    170
# 2020    155
# 2019    129
# 2018    128
# 2016    111
# 2017    110
# 2015     75
# 2014     41
# 2013     37
# 2012     25
# 2009     20
# 2011     18
# 2006     13
# 2010     13
# 2008     10
# 2007      9
# 2003      9
# 2004      8
# 2005      7
# 2002      5
# 2000      4
# 1998      4
# 1999      2
# 2001      2
# 1995      1
# 1994      1
# 1996      1
# 1997      1
# Name: count, dtype: int64

# %% [markdown]
# ### Identificar outliers

# %%
contagem_os = df['supported_os'].value_counts()
outliers_os = contagem_os[contagem_os < 5]
print(outliers_os)
# Out:
# supported_os
# win, linux, music    1
# win, mac, linux,     1
# Name: count, dtype: int64

# %% [markdown]
# # Analise exploratoria de dados

# %% [markdown]
# ### Top 10 tags e desenvolvedores

# %%
top_tags = df['user_defined_tags'].value_counts().head(10).sort_values(ascending=True)
top_tags.plot(kind='barh')
plt.title("Top 10 Tags")
plt.xlabel("Quantidade")
plt.ylabel("Tags")
plt.show()

# %%
top_developers = df['developer'].value_counts().head(10).sort_values(ascending=True)
top_developers.plot(kind='barh')
plt.title("Top 10 Developers")
plt.xlabel("Quantidade")
plt.ylabel("Developers")
plt.show()

# %% [markdown]
# ### Relacao dificuldade x tempo

# %%
sns.lineplot(data=df, x='length', y='difficulty', errorbar=None)
plt.title("Game Length vs Difficulty")
plt.xlabel("Length (hours)")
plt.ylabel("Difficulty")
plt.tight_layout()
plt.show()

print(df[["length", "difficulty"]].corr())
# Out:
#               length  difficulty
# length      1.000000    0.309647
# difficulty  0.309647    1.000000

# %% [markdown]
# ### Relacao preco x vendas

# %%
sns.scatterplot(data=df, x='price', y='estimated_downloads')
plt.title("Game Price vs Estimated Downloads")
plt.xlabel("Price ($)")
plt.ylabel("Estimated Downloads")
plt.tight_layout()
plt.show()

print(df[["price", "estimated_downloads"]].corr())
# Out:
#                         price  estimated_downloads
# price                1.000000             0.061999
# estimated_downloads  0.061999             1.000000

# %% [markdown]
# ### Relacao vendas por tag

# %%
tag_sales = df.groupby('user_defined_tags')['estimated_downloads'].sum().reset_index()

top_tags = tag_sales.sort_values(by='estimated_downloads', ascending=False).head(20)

plt.figure(figsize=(12, 8))
sns.barplot(x='estimated_downloads', y='user_defined_tags', data=top_tags)
plt.title('Top Tags por Vendas')
plt.xlabel('Total Estimated Downloads (Millions)')
plt.ylabel('User Tag')
plt.show()

# %%
df.to_csv('dataset_final.csv', index=False)
